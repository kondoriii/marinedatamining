# %% [markdown]
# <a href="https://colab.research.google.com/github/kondoriii/marinedatamining/blob/main/%ED%95%B4%EC%82%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A7%88%EC%9D%B4%EB%8B%9D_9%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
from scipy import stats

df = pd.read_csv('branch_satisfaction.csv')

print('[데이터 미리보기]')
print(df.head(), '\n')

a = df[df['branch']=='A']['score']
b = df[df['branch']=='B']['score']
c = df[df['branch']=='C']['score']

result = stats.f_oneway(a,b,c)
means = df.groupby('branch')['score'].mean().sort_values(ascending=False)

print('[분석결과]')
print('지점별 평균')
print(means, '\n')
print('F-statistic:', round(result.statistic, 4))
print('p-value:', round(result.pvalue, 6))
print('평균이 가장 높은 지점:', means.index[0])

print('\n[결과 해석]')
if result.pvalue < 0.05:
    print('지점 간 평균 고객만족도 차이가 유의합니다.')
else:
    print('지점 간 평균 고객만족도 차이가 유의하지 않습니다.')
# Out:
#      <input type="file" id="files-9dcfaac3-ee2a-4b7e-8abf-917c20f1f662" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dcfaac3-ee2a-4b7e-8abf-917c20f1f662">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

from pathlib import Path
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm

file_path = 'ad_age_sales.csv'

df = pd.read_csv(file_path)

print('[데이터 미리보기]')
print(df.head(), '\n')
# Out:
#      <input type="file" id="files-dfbf968d-c571-4cc4-b339-7abca47bb288" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfbf968d-c571-4cc4-b339-7abca47bb288">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = smf.ols(
    'sales_amount ~ C(ad_type) + C(age_group) + C(ad_type):C(age_group)',
    data=df
).fit()

anova_table = anova_lm(model, typ=2)

print('[ANOVA 결과표]')
print(anova_table, '\n')

p_ad = anova_table.loc['C(ad_type)', 'PR(>F)']
p_age = anova_table.loc['C(age_group)', 'PR(>F)']
p_inter = anova_table.loc['C(ad_type):C(age_group)', 'PR(>F)']

print('[핵심 p-value]')
print('광고유형 p-value:', p_ad)
print('연령대 p-value:', p_age)
print('상호작용 p-value:', p_inter)


print('\n[결과 해석]')
if p_inter < 0.05:
    print('상호작용 효과가 유의 → 광고 효과는 연령대에 따라 달라짐')
else:
    print('상호작용 효과 없음 → 주효과 중심 해석')
# Out:
# [ANOVA 결과표]
#                                sum_sq     df          F        PR(>F)
# C(ad_type)                7050.113701    1.0  66.683189  4.809132e-13
# C(age_group)              4944.440732    2.0  23.383387  3.093055e-09
# C(ad_type):C(age_group)   1362.156532    2.0   6.441949  2.235659e-03
# Residual                 12052.707415  114.0        NaN           NaN
#
# [핵심 p-value]
# 광고유형 p-value: 4.809132100282664e-13
# 연령대 p-value: 3.0930546471646577e-09
# 상호작용 p-value: 0.0022356585218461854
#
# [결과 해석]
# 상호작용 효과가 유의 → 광고 효과는 연령대에 따라 달라짐
